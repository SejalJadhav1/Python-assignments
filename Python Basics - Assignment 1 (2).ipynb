# %% [markdown]
# # Python Basics Assignment 1

# %% [markdown]
# Q.1 Ans : values = "hello" , -87.8 , 6
#           expressions = * , - , / ,+

# %% [markdown]
# Q.2 Ans : String is any value inside inverted commas whereas a varaible is a name of an object to
#               which it is assigned.

# %% [markdown]
#  Q.3 Ans : Integer - contains only integer value
#               string - any value inside inverted commas
#               Boolean - returns TRUE and FALSE as output

# %% [markdown]
# Q.4 Ans : Expression consists of the variable name, its value, along with operators if
#               any.

# %% [markdown]
# Q.5 Ans : Expression is made up of  opertors ,variable name, and its value whereas statement
#               is an instruction that the program can interpret.

# %% [markdown]
#  Q.6 Ans : Variable bacon contain 22

# %% [markdown]
#  Q.7 Ans : spamspamspam

# %% [markdown]
# Q.8 Ans : The variable name can never be numeric.

# %% [markdown]
# Q.9 Ans : int() , float() , str()

# %% [markdown]
# Q.10 Ans :"i have eaten" + str(99) + "burritos"
